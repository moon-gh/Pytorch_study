# %%
import torch

# %%
tensor = torch.tensor([1, 2, 3])
print(tensor)
# Out:
# tensor([1, 2, 3])

# %%
model = torch.nn.Sequential(
    torch.nn.Linear(10, 5),
    torch.nn.ReLU(),
    torch.nn.Linear(5, 2)
)
